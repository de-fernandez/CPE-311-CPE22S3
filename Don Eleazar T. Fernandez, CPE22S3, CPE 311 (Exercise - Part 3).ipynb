# %%
import pandas as pd

# %%
meteorites = pd.read_csv("Meteorite_Landings.csv", nrows = 5)
meteorites
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5        21  Fell
# 1    Aarhus    2    Valid           H6       720  Fell
# 2      Abee    6    Valid          EH4    107000  Fell
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell
# 4   Achiras  370    Valid           L6       780  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites["name"]
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import requests

response = requests.get(
    "https://data.nasa.gov/resource/gh4g-9sfh.json",
    params = {"$limit": 50_000}
)

if response.ok:
    payload = response.json()
else:
    print(f"Request was not successful and returned code: {response.status_code}.")
    payload = None

# %%
payload[0]
# Out:
# {'name': 'Aachen',
#  'id': '1',
#  'nametype': 'Valid',
#  'recclass': 'L5',
#  'mass': '21',
#  'fall': 'Fell',
#  'year': '1880-01-01T00:00:00.000',
#  'reclat': '50.775000',
#  'reclong': '6.083330',
#  'geolocation': {'latitude': '50.775', 'longitude': '6.08333'}}

# %%
df = pd.DataFrame(payload)
df.head(3)
# Out:
#      name id nametype recclass    mass  fall                     year  \
# 0  Aachen  1    Valid       L5      21  Fell  1880-01-01T00:00:00.000
# 1  Aarhus  2    Valid       H6     720  Fell  1951-01-01T00:00:00.000
# 2    Abee  6    Valid      EH4  107000  Fell  1952-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN

# %%
meteorites = pd.read_csv("Meteorite_Landings.csv")
meteorites.shape
# Out:
# (45716, 10)

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
meteorites.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
meteorites.tail(5)
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 45711  01/01/1990 12:00:00 AM  29.03700   17.01850       (29.037, 17.0185)
# 45712  01/01/1999 12:00:00 AM  13.78333    8.96667     (13.78333, 8.96667)
# 45713  01/01/1939 12:00:00 AM  49.25000   17.66667       (49.25, 17.66667)
# 45714  01/01/2003 12:00:00 AM  49.78917   41.50460     (49.78917, 41.5046)
# 45715  01/01/1976 12:00:00 AM  33.98333 -115.68333  (33.98333, -115.68333)

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
meteorites[["name", "year"]]
# Out:
#              name                    year
# 0          Aachen  01/01/1880 12:00:00 AM
# 1          Aarhus  01/01/1951 12:00:00 AM
# 2            Abee  01/01/1952 12:00:00 AM
# 3        Acapulco  01/01/1976 12:00:00 AM
# 4         Achiras  01/01/1902 12:00:00 AM
# ...           ...                     ...
# 45711  Zillah 002  01/01/1990 12:00:00 AM
# 45712      Zinder  01/01/1999 12:00:00 AM
# 45713        Zlin  01/01/1939 12:00:00 AM
# 45714   Zubkovsky  01/01/2003 12:00:00 AM
# 45715  Zulu Queen  01/01/1976 12:00:00 AM
#
# [45716 rows x 2 columns]

# %%
meteorites[["name", "mass (g)"]]
# Out:
#              name  mass (g)
# 0          Aachen      21.0
# 1          Aarhus     720.0
# 2            Abee  107000.0
# 3        Acapulco    1914.0
# 4         Achiras     780.0
# ...           ...       ...
# 45711  Zillah 002     172.0
# 45712      Zinder      46.0
# 45713        Zlin       3.3
# 45714   Zubkovsky    2167.0
# 45715  Zulu Queen     200.0
#
# [45716 rows x 2 columns]

# %%
meteorites[100:104]
# Out:
#               name     id nametype       recclass  mass (g)  fall  \
# 100         Benton   5026    Valid            LL6    2840.0  Fell
# 101         Berduc  48975    Valid             L6     270.0  Fell
# 102         Béréba   5028    Valid  Eucrite-mmict   18000.0  Fell
# 103  Berlanguillas   5029    Valid             L6    1440.0  Fell
#
#                        year    reclat   reclong          GeoLocation
# 100  01/01/1949 12:00:00 AM  45.95000 -67.55000      (45.95, -67.55)
# 101  01/01/2008 12:00:00 AM -31.91000 -58.32833  (-31.91, -58.32833)
# 102  01/01/1924 12:00:00 AM  11.65000  -3.65000       (11.65, -3.65)
# 103  01/01/1811 12:00:00 AM  41.68333  -3.80000     (41.68333, -3.8)

# %%
meteorites.iloc[100:104, [0, 3, 4, 6]]
# Out:
#               name       recclass  mass (g)                    year
# 100         Benton            LL6    2840.0  01/01/1949 12:00:00 AM
# 101         Berduc             L6     270.0  01/01/2008 12:00:00 AM
# 102         Béréba  Eucrite-mmict   18000.0  01/01/1924 12:00:00 AM
# 103  Berlanguillas             L6    1440.0  01/01/1811 12:00:00 AM

# %%
meteorites.loc[100:104, "mass (g)": "year"]
# Out:
#      mass (g)  fall                    year
# 100    2840.0  Fell  01/01/1949 12:00:00 AM
# 101     270.0  Fell  01/01/2008 12:00:00 AM
# 102   18000.0  Fell  01/01/1924 12:00:00 AM
# 103    1440.0  Fell  01/01/1811 12:00:00 AM
# 104     960.0  Fell  01/01/2004 12:00:00 AM

# %%
meteorites.iloc[-1, [-1]]
# Out:
# GeoLocation    (33.98333, -115.68333)
# Name: 45715, dtype: object

# %%
meteorites.iloc[:, [-1]]
# Out:
#                   GeoLocation
# 0           (50.775, 6.08333)
# 1        (56.18333, 10.23333)
# 2          (54.21667, -113.0)
# 3           (16.88333, -99.9)
# 4         (-33.16667, -64.95)
# ...                       ...
# 45711       (29.037, 17.0185)
# 45712     (13.78333, 8.96667)
# 45713       (49.25, 17.66667)
# 45714     (49.78917, 41.5046)
# 45715  (33.98333, -115.68333)
#
# [45716 rows x 1 columns]

# %%
(meteorites["mass (g)"] > 50) & (meteorites.fall == "Found")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711     True
# 45712    False
# 45713    False
# 45714     True
# 45715     True
# Length: 45716, dtype: bool

# %%
meteorites[(meteorites["mass (g)"] > 1e6) & (meteorites.fall == "Fell")]
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.query("`mass (g)` > 1e6 and fall == 'Fell'")
# Out:
#               name     id nametype    recclass    mass (g)  fall  \
# 29         Allende   2278    Valid         CV3   2000000.0  Fell
# 419          Jilin  12171    Valid          H5   4000000.0  Fell
# 506  Kunya-Urgench  12379    Valid          H5   1100000.0  Fell
# 707  Norton County  17922    Valid     Aubrite   1100000.0  Fell
# 920   Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 29   01/01/1969 12:00:00 AM  26.96667 -105.31667  (26.96667, -105.31667)
# 419  01/01/1976 12:00:00 AM  44.05000  126.16667      (44.05, 126.16667)
# 506  01/01/1998 12:00:00 AM  42.25000   59.20000           (42.25, 59.2)
# 707  01/01/1948 12:00:00 AM  39.68333  -99.86667   (39.68333, -99.86667)
# 920  01/01/1947 12:00:00 AM  46.16000  134.65333      (46.16, 134.65333)

# %%
meteorites.value_counts()
# Out:
# name                         id     nametype  recclass  mass (g)  fall   year                    reclat      reclong     GeoLocation
# Aachen                       1      Valid     L5        21.00     Fell   01/01/1880 12:00:00 AM   50.775000  6.083330    (50.775, 6.08333)          1
# Queen Alexandra Range 90215  19020  Valid     L5        358.90    Found  01/01/1990 12:00:00 AM  -84.606700  162.167080  (-84.6067, 162.16708)      1
# Queen Alexandra Range 90217  19022  Valid     L5        327.70    Found  01/01/1990 12:00:00 AM  -84.595030  162.319900  (-84.59503, 162.3199)      1
# Queen Alexandra Range 90218  19023  Valid     L5        926.50    Found  01/01/1990 12:00:00 AM  -84.610170  162.153880  (-84.61017, 162.15388)     1
# Queen Alexandra Range 90219  19024  Valid     L5        316.00    Found  01/01/1990 12:00:00 AM  -84.611160  162.145660  (-84.61116, 162.14566)     1
# ...

# %%
meteorites.fall.value_counts()
# Out:
# fall
# Found    44609
# Fell      1107
# Name: count, dtype: int64

# %%
meteorites.value_counts(subset=["nametype", "fall"], normalize = True)
# Out:
# nametype  fall
# Valid     Found    0.974145
#           Fell     0.024215
# Relict    Found    0.001641
# Name: proportion, dtype: float64

# %%
meteorites["mass (g)"].mean()
# Out:
# 13278.078548601512

# %%
meteorites["mass (g)"].quantile([0.01, 0.05, 0.5, 0.95, 0.99])
# Out:
# 0.01        0.44
# 0.05        1.10
# 0.50       32.60
# 0.95     4000.00
# 0.99    50600.00
# Name: mass (g), dtype: float64

# %%
meteorites["mass (g)"].median()
# Out:
# 32.6

# %%
meteorites["mass (g)"].max()
# Out:
# 60000000.0

# %%
meteorites.loc[meteorites["mass (g)"].idxmax()]
# Out:
# name                             Hoba
# id                              11890
# nametype                        Valid
# recclass                    Iron, IVB
# mass (g)                   60000000.0
# fall                            Found
# year           01/01/1920 12:00:00 AM
# reclat                      -19.58333
# reclong                      17.91667
# GeoLocation     (-19.58333, 17.91667)
# Name: 16392, dtype: object

# %%
meteorites.recclass.nunique()
# Out:
# 466

# %%
meteorites.recclass.unique()
# Out:
# array(['L5', 'H6', 'EH4', 'Acapulcoite', 'L6', 'LL3-6', 'H5', 'L',
#        'Diogenite-pm', 'Unknown', 'H4', 'H', 'Iron, IVA', 'CR2-an', 'LL5',
#        'CI1', 'L/LL4', 'Eucrite-mmict', 'CV3', 'Ureilite-an',
#        'Stone-uncl', 'L3', 'Angrite', 'LL6', 'L4', 'Aubrite',
#        'Iron, IIAB', 'Iron, IAB-sLL', 'Iron, ungrouped', 'CM2', 'OC',
#        'Mesosiderite-A1', 'LL4', 'C2-ung', 'LL3.8', 'Howardite',
#        'Eucrite-pmict', 'Diogenite', 'LL3.15', 'LL3.9', 'Iron, IAB-MG',
#        'H/L3.9', 'Iron?', 'Eucrite', 'H4-an', 'L/LL6', 'Iron, IIIAB',
#        'H/L4', 'H4-5', 'L3.7', 'LL3.4', 'Martian (chassignite)', 'EL6',
#        'H3.8', 'H3-5', 'H5-6', 'Mesosiderite', 'H5-7', 'L3-6', 'H4-6',
#        'Ureilite', 'Iron, IID', 'Mesosiderite-A3/4', 'CO3.3', 'H3',
#        'EH3/4-an', 'Iron, IIE', 'L/LL5', 'H3.7', 'CBa', 'H4/5', 'H3/4',
#        'H?', 'H3-6', 'L3.4', 'Iron, IAB-sHL', 'L3.7-6', 'EH7-an', 'Iron',
#        'CR2', 'CO3.2', 'K3', 'L5/6', 'CK4', 'Iron, IIE-an', 'L3.6',
# ...

# %%
meteorites.describe(include = "all")
# Out:
#           name            id nametype recclass      mass (g)   fall  \
# count    45716  45716.000000    45716    45716  4.558500e+04  45716
# unique   45716           NaN        2      466           NaN      2
# top     Aachen           NaN    Valid       L6           NaN  Found
# freq         1           NaN    45641     8285           NaN  44609
# mean       NaN  26889.735104      NaN      NaN  1.327808e+04    NaN
# std        NaN  16860.683030      NaN      NaN  5.749889e+05    NaN
# min        NaN      1.000000      NaN      NaN  0.000000e+00    NaN
# 25%        NaN  12688.750000      NaN      NaN  7.200000e+00    NaN
# 50%        NaN  24261.500000      NaN      NaN  3.260000e+01    NaN
# 75%        NaN  40656.750000      NaN      NaN  2.026000e+02    NaN
# max        NaN  57458.000000      NaN      NaN  6.000000e+07    NaN
#
#                           year        reclat       reclong GeoLocation
# count                    45425  38401.000000  38401.000000       38401
# ...

# %% [markdown]
# **Exercise (Part 1)**

# %% [markdown]
# Using the 2019_Yellow_Taxi_Trip_Data.csv dataset, accomplish the following items and submit a PDF of the notebook:
#
# 1. Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.
# 2. Find the dimensions (number of rows and number of columns) in the data.
# 3. Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.
# 4. Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %% [markdown]
# 1. Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
data = pd.read_csv("2019_Yellow_Taxi_Trip_Data.csv")
dframe = pd.DataFrame(data)
dframe.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %% [markdown]
# 2. Find the dimensions (number of rows and number of columns) in the data.

# %%
dframe.shape
# Out:
# (10000, 18)

# %% [markdown]
# The rows is 10000.
# The columns is 18.

# %% [markdown]
# 3. Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.

# %%
result = dframe.iloc[:, [4, 10, 13, 14, 16]]
result.describe()
# Out:
#        trip_distance   fare_amount    tip_amount  tolls_amount  total_amount
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        3.015250     15.106313      2.634494      0.623447     22.564659
# std         4.148063     13.954762      3.409800      6.437507     19.209255
# min         0.000000    -52.000000      0.000000     -6.120000    -65.920000
# 25%         0.920000      7.000000      0.000000      0.000000     12.375000
# 50%         1.500000     10.000000      2.000000      0.000000     16.300000
# 75%         2.760000     16.000000      3.250000      0.000000     22.880000
# max        38.110000    176.000000     43.000000    612.000000    671.800000

# %% [markdown]
# 4. Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
result.loc[result["trip_distance"].idxmax()]
# Out:
# trip_distance     38.11
# fare_amount      176.00
# tip_amount        18.29
# tolls_amount       6.12
# total_amount     201.21
# Name: 8338, dtype: float64

# %% [markdown]
# Reflection: In this activity, I had a hard time on the last part as I get confused on how would I isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance. All throughout the activity, I was able to apply all what I have understood on the lecture.

# %%
taxis = pd.read_csv("2019_Yellow_Taxi_Trip_Data.csv")

# %%
mask = taxis.columns.str.contains("id$|store_and_fwd_flag", regex = True)
columns_to_drop = taxis.columns[mask]
columns_to_drop
# Out:
# Index(['vendorid', 'ratecodeid', 'store_and_fwd_flag', 'pulocationid',
#        'dolocationid'],
#       dtype='object')

# %%
taxis = taxis.drop(columns = columns_to_drop)
taxis.head()
# Out:
#       tpep_pickup_datetime    tpep_dropoff_datetime  passenger_count  \
# 0  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000                1
# 1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000                1
# 2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000                1
# 3  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000                1
# 4  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000                1
#
#    trip_distance  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0           7.93             1         29.5    1.0      0.5        7.98
# 1           2.00             1         10.5    1.0      0.5        0.00
# 2           1.36             1          9.5    1.0      0.5        2.00
# 3           1.00             1         13.0    1.0      0.5        4.32
# 4           1.96             1         10.5    1.0      0.5        0.50
#
#    tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# ...

# %%
taxis = taxis.rename(
    columns={
        'tpep_pickup_datetime': 'pickup',
        'tpep_dropoff_datetime': 'dropoff'
    }
)
taxis.columns
# Out:
# Index(['pickup', 'dropoff', 'passenger_count', 'trip_distance', 'payment_type',
#        'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount', 'congestion_surcharge'],
#       dtype='object')

# %%
taxis[['pickup', 'dropoff']] = taxis[['pickup', 'dropoff']].apply(pd.to_datetime)
taxis.dtypes
# Out:
# pickup                   datetime64[ns]
# dropoff                  datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# dtype: object

# %%
taxis = taxis.assign(
    elapsed_time = lambda x: x.dropoff - x.pickup,
    cost_before_tip = lambda x: x.total_amount - x.tip_amount,
    tip_pct = lambda x: x.tip_amount / x.cost_before_tip,
    fees = lambda x: x.cost_before_tip - x.fare_amount,
    avg_speed = lambda x: x.trip_distance.div(
        x.elapsed_time.dt.total_seconds()/60/60
    )
)
#It create columns with computed values

taxis.dtypes
# Out:
# pickup                    datetime64[ns]
# dropoff                   datetime64[ns]
# passenger_count                    int64
# trip_distance                    float64
# payment_type                       int64
# fare_amount                      float64
# extra                            float64
# mta_tax                          float64
# tip_amount                       float64
# tolls_amount                     float64
# improvement_surcharge            float64
# total_amount                     float64
# congestion_surcharge             float64
# elapsed_time             timedelta64[ns]
# cost_before_tip                  float64
# tip_pct                          float64
# fees                             float64
# avg_speed                        float64
# dtype: object

# %%
taxis.head(2)
# Out:
#                pickup             dropoff  passenger_count  trip_distance  \
# 0 2019-10-23 16:39:42 2019-10-23 17:14:10                1           7.93
# 1 2019-10-23 16:32:08 2019-10-23 16:45:26                1           2.00
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         29.5    1.0      0.5        7.98          6.12
# 1             1         10.5    1.0      0.5        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge    elapsed_time  \
# 0                    0.3          47.9                   2.5 0 days 00:34:28
# 1                    0.3          12.3                   0.0 0 days 00:13:18
#
#    cost_before_tip  tip_pct   fees  avg_speed
# 0            39.92   0.1999  10.42  13.804642
# 1            12.30   0.0000   1.80   9.022556

# %%
taxis.sort_values(["passenger_count", "pickup"], ascending = [False, True]).head()
# Out:
#                   pickup             dropoff  passenger_count  trip_distance  \
# 5997 2019-10-23 15:55:19 2019-10-23 16:08:25                6           1.58
# 443  2019-10-23 15:56:59 2019-10-23 16:04:33                6           1.46
# 8722 2019-10-23 15:57:33 2019-10-23 16:03:34                6           0.62
# 4198 2019-10-23 15:57:38 2019-10-23 16:05:07                6           1.18
# 8238 2019-10-23 15:58:31 2019-10-23 16:29:29                6           3.23
#
#       payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 5997             2         10.0    1.0      0.5         0.0           0.0
# 443              2          7.5    1.0      0.5         0.0           0.0
# 8722             1          5.5    1.0      0.5         0.7           0.0
# 4198             1          7.0    1.0      0.5         1.0           0.0
# 8238             2         19.5    1.0      0.5         0.0           0.0
#
# ...

# %%
taxis.nlargest(3, "elapsed_time")
#It shows the largest value in elapsed_time
# Out:
#                   pickup             dropoff  passenger_count  trip_distance  \
# 7576 2019-10-23 16:52:51 2019-10-24 16:51:44                1           3.75
# 6902 2019-10-23 16:51:42 2019-10-24 16:50:22                1          11.19
# 4975 2019-10-23 16:18:51 2019-10-24 16:17:30                1           0.70
#
#       payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 7576             1         17.5    1.0      0.5         0.0           0.0
# 6902             2         39.5    1.0      0.5         0.0           0.0
# 4975             2          7.0    1.0      0.5         0.0           0.0
#
#       improvement_surcharge  total_amount  congestion_surcharge  \
# 7576                    0.3          21.8                   2.5
# 6902                    0.3          41.3                   0.0
# 4975                    0.3          11.3                   2.5
#
#         elapsed_time  cost_before_tip  tip_pct  fees  avg_speed
# ...

# %%
taxis.nlargest(3, "fare_amount")
# Out:
#                   pickup             dropoff  passenger_count  trip_distance  \
# 8338 2019-10-23 16:50:53 2019-10-24 15:32:55                1          38.11
# 853  2019-10-23 16:07:39 2019-10-23 17:37:05                3          19.09
# 4714 2019-10-23 16:33:17 2019-10-23 17:56:49                2          26.30
#
#       payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 8338             1       176.00    0.0      0.5       18.29          6.12
# 853              2       160.00    0.0      0.0        0.00         18.62
# 4714             1       111.75    0.0      0.0        0.00         18.62
#
#       improvement_surcharge  total_amount  congestion_surcharge  \
# 8338                    0.3        201.21                   0.0
# 853                     0.3        181.42                   2.5
# 4714                    0.3        130.67                   0.0
#
#         elapsed_time  cost_before_tip   tip_pct   fees  avg_speed
# ...

# %% [markdown]
# **Exercise (Part 2)**

# %% [raw]
# Read in the meteorite data from the Meteorite_Landings.csv file, rename the mass (g) column to mass, and drop all the latitude and longtitude columns. Sort the result by mass in descending order.

# %%
# Import meteorite data from the Meteorite_Landings.csv file
meteorite1 = pd.read_csv("Meteorite_Landings.csv")
meteorite1
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
# Rename the mass (g) column to mass
meteorite1 = meteorite1.rename(
    columns={
        'mass (g)': 'mass',
    }
)
meteorite1
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
# Drop all the latitude and longtitude columns
meteorite1 = meteorite1.drop(columns = ["reclat", "reclong"])
meteorite1
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year             GeoLocation
# ...

# %%
meteorite1 = meteorite1.sort_values("mass", ascending = False)
meteorite1
# Out:
#                   name     id nametype      recclass        mass   fall  \
# 16392             Hoba  11890    Valid     Iron, IVB  60000000.0  Found
# 5373         Cape York   5262    Valid   Iron, IIIAB  58200000.0  Found
# 5365   Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# 5370     Canyon Diablo   5257    Valid  Iron, IAB-MG  30000000.0  Found
# 3455           Armanty   2335    Valid    Iron, IIIE  28000000.0  Found
# ...                ...    ...      ...           ...         ...    ...
# 38282   Wei-hui-fu (a)  24231    Valid          Iron         NaN  Found
# 38283   Wei-hui-fu (b)  24232    Valid          Iron         NaN  Found
# 38285          Weiyuan  24233    Valid  Mesosiderite         NaN  Found
# 41472    Yamato 792768  28117    Valid           CM2         NaN  Found
# 45698    Zapata County  30393    Valid          Iron         NaN  Found
#
#                          year             GeoLocation
# ...

# %%
taxis = taxis.set_index("pickup")
taxis.head(3)
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2019-10-23 16:39:42 2019-10-23 17:14:10                1           7.93
# 2019-10-23 16:32:08 2019-10-23 16:45:26                1           2.00
# 2019-10-23 16:08:44 2019-10-23 16:21:11                1           1.36
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# 2019-10-23 16:39:42             1         29.5    1.0      0.5        7.98
# 2019-10-23 16:32:08             1         10.5    1.0      0.5        0.00
# 2019-10-23 16:08:44             1          9.5    1.0      0.5        2.00
#
#                      tolls_amount  improvement_surcharge  total_amount  \
# pickup
# 2019-10-23 16:39:42          6.12                    0.3          47.9
# 2019-10-23 16:32:08          0.00                    0.3          12.3
# 2019-10-23 16:08:44          0.00                    0.3          15.8
#
# ...

# %%
taxis.sort_index(axis = 0)
# This sort the by index, but axis = 1 is sorted by columns
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2019-10-23 07:05:34 2019-10-23 08:03:16                3          14.68
# 2019-10-23 07:48:58 2019-10-23 07:52:09                1           0.67
# 2019-10-23 08:02:09 2019-10-24 07:42:32                1           8.38
# 2019-10-23 08:18:47 2019-10-23 08:36:05                1           2.39
# 2019-10-23 09:27:16 2019-10-23 09:33:13                2           1.11
# ...                                 ...              ...            ...
# 2019-10-24 07:23:52 2019-10-24 08:08:52                1           0.00
# 2019-10-24 07:29:52 2019-10-24 07:33:24                1           0.54
# 2019-10-24 07:58:31 2019-10-24 08:47:05                1           0.00
# 2019-10-24 08:07:45 2019-10-24 08:07:50                2           0.00
# 2019-10-24 08:19:11 2019-10-24 09:00:35                0          13.20
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# ...

# %%
taxis["2019-10-23 07:45": "2019-10-23 08"]
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2019-10-23 07:48:58 2019-10-23 07:52:09                1           0.67
# 2019-10-23 08:02:09 2019-10-24 07:42:32                1           8.38
# 2019-10-23 08:18:47 2019-10-23 08:36:05                1           2.39
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# 2019-10-23 07:48:58             2          4.5    1.0      0.5         0.0
# 2019-10-23 08:02:09             1         32.0    1.0      0.5         5.5
# 2019-10-23 08:18:47             2         12.5    1.0      0.5         0.0
#
#                      tolls_amount  improvement_surcharge  total_amount  \
# pickup
# 2019-10-23 07:48:58           0.0                    0.3           8.8
# 2019-10-23 08:02:09           0.0                    0.3          41.8
# 2019-10-23 08:18:47           0.0                    0.3          16.8
#
# ...

# %%
taxis["2019-10-23": "2019-10-23"]
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2019-10-23 07:05:34 2019-10-23 08:03:16                3          14.68
# 2019-10-23 07:48:58 2019-10-23 07:52:09                1           0.67
# 2019-10-23 08:02:09 2019-10-24 07:42:32                1           8.38
# 2019-10-23 08:18:47 2019-10-23 08:36:05                1           2.39
# 2019-10-23 09:27:16 2019-10-23 09:33:13                2           1.11
# ...                                 ...              ...            ...
# 2019-10-23 17:59:53 2019-10-23 18:12:56                2           1.60
# 2019-10-23 17:59:53 2019-10-23 18:19:12                1           2.39
# 2019-10-23 18:00:03 2019-10-23 18:04:56                1           0.94
# 2019-10-23 18:01:21 2019-10-23 18:08:00                5           1.25
# 2019-10-23 18:03:03 2019-10-23 18:10:45                1           0.76
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# ...

# %%
taxis.loc["2019-10-23 08"]
# Out:
#                                 dropoff  passenger_count  trip_distance  \
# pickup
# 2019-10-23 08:02:09 2019-10-24 07:42:32                1           8.38
# 2019-10-23 08:18:47 2019-10-23 08:36:05                1           2.39
#
#                      payment_type  fare_amount  extra  mta_tax  tip_amount  \
# pickup
# 2019-10-23 08:02:09             1         32.0    1.0      0.5         5.5
# 2019-10-23 08:18:47             2         12.5    1.0      0.5         0.0
#
#                      tolls_amount  improvement_surcharge  total_amount  \
# pickup
# 2019-10-23 08:02:09           0.0                    0.3          41.8
# 2019-10-23 08:18:47           0.0                    0.3          16.8
#
#                      congestion_surcharge    elapsed_time  cost_before_tip  \
# pickup
# 2019-10-23 08:02:09                   2.5 0 days 23:40:23             36.3
# 2019-10-23 08:18:47                   2.5 0 days 00:17:18             16.8
#
# ...

# %%
taxis = taxis.reset_index()
taxis.head()
# This the index
# Out:
#                pickup             dropoff  passenger_count  trip_distance  \
# 0 2019-10-23 07:05:34 2019-10-23 08:03:16                3          14.68
# 1 2019-10-23 07:48:58 2019-10-23 07:52:09                1           0.67
# 2 2019-10-23 08:02:09 2019-10-24 07:42:32                1           8.38
# 3 2019-10-23 08:18:47 2019-10-23 08:36:05                1           2.39
# 4 2019-10-23 09:27:16 2019-10-23 09:33:13                2           1.11
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         50.0    1.0      0.5         4.0           0.0
# 1             2          4.5    1.0      0.5         0.0           0.0
# 2             1         32.0    1.0      0.5         5.5           0.0
# 3             2         12.5    1.0      0.5         0.0           0.0
# 4             2          6.0    1.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge    elapsed_time  \
# ...

# %% [markdown]
# **Exercise (Part 3)**

# %%
meteorite2 = pd.read_csv("Meteorite_Landings.csv")
meteorite2
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# ...

# %%
# Update the year column to only contain the year# Import meteorite data from the Meteorite_Landings.csv file
meteorite2_1 = lambda x: x.str[6:10]
meteorite2["year"] = meteorite2_1(meteorite2["year"])
meteorite2
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#        year    reclat    reclong             GeoLocation
# ...

# %%
# Convert it to a numeric data type
meteorite2["year"] = meteorite2["year"].apply(pd.to_numeric)
meteorite2.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year           float64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
# Create a new column indicating whether the meteorite was observed falling before 1970
meteorite2["Observed_Falling"] = (meteorite2.year < 1970.0) & (meteorite2.fall == "Fell")
meteorite2
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation  Observed_Falling
# ...

# %%
# Set the index to the id column and extract all the rows with IDs between 10036 and 10040 (inclusive) with loc[]
meteorite2.set_index("id")
# Out:
#              name nametype              recclass  mass (g)   fall    year  \
# id
# 1          Aachen    Valid                    L5      21.0   Fell  1880.0
# 2          Aarhus    Valid                    H6     720.0   Fell  1951.0
# 6            Abee    Valid                   EH4  107000.0   Fell  1952.0
# 10       Acapulco    Valid           Acapulcoite    1914.0   Fell  1976.0
# 370       Achiras    Valid                    L6     780.0   Fell  1902.0
# ...           ...      ...                   ...       ...    ...     ...
# 31356  Zillah 002    Valid               Eucrite     172.0  Found  1990.0
# 30409      Zinder    Valid  Pallasite, ungrouped      46.0  Found  1999.0
# 30410        Zlin    Valid                    H4       3.3  Found  1939.0
# 31357   Zubkovsky    Valid                    L6    2167.0  Found  2003.0
# 30414  Zulu Queen    Valid                  L3.7     200.0  Found  1976.0
#
#          reclat    reclong             GeoLocation  Observed_Falling
# id
# ...

# %%
meteorite2.sort_index()
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation  Observed_Falling
# ...

# %%
meteorite2.iloc[10036: 10040]
# Out:
#                          name    id nametype    recclass  mass (g)   fall  \
# 10036  Elephant Moraine 90022  8432    Valid         CK5      15.5  Found
# 10037  Elephant Moraine 90023  8433    Valid         CK5      31.5  Found
# 10038  Elephant Moraine 90024  8434    Valid  Eucrite-br      22.8  Found
# 10039  Elephant Moraine 90025  8435    Valid         CK5      45.8  Found
#
#          year    reclat    reclong             GeoLocation  Observed_Falling
# 10036  1990.0 -76.28573  156.45721  (-76.28573, 156.45721)             False
# 10037  1990.0 -76.27507  156.41038  (-76.27507, 156.41038)             False
# 10038  1990.0 -76.28843  156.47872  (-76.28843, 156.47872)             False
# 10039  1990.0 -76.28200  156.39926    (-76.282, 156.39926)             False
